# %%
import matplotlib.pyplot as plt 
import matplotlib as mpl
import numpy as np
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
# %config InlineBackend.figure_format = 'retina'

WRYH = mpl.font_manager.FontProperties(fname='WeiRuanYaHei-1.ttf') 

plt.rcParams['font.sans-serif'] = ['Songti SC']

# %%
## 下面是左右两边的数据

t1= [237,106,22,2,5]
t2 = [1942,932,377,51,33]

# 计算百分比 不需要动
y1 = [t1[i]/sum(t1)*100 for i in range(len(t1))]
y2 = [t2[i]/sum(t2)*100 for i in range(len(t2))]
y2 = [-y2[i] for i in range(len(t1))]  
y1 = list(np.round(y1[::-1])) 
y2 = list(np.round(y2[::-1]))
x = [i for i in range(len(t1))]



plt.figure(figsize=(9, 5), dpi=120)

ax = plt.gca()

ax.spines['right'].set_color('None')
ax.spines['left'].set_color('None')
ax.spines['top'].set_color('None')
ax.spines['bottom'].set_color('None')

plt.yticks([])
plt.xticks([])


plt.barh(x, y1, edgecolor='black', height=0.7, left=11,color = '#4D70F0')
plt.barh(x, y2, edgecolor='black', height=0.7, left=-11,color = '#00C5D2')

## 下面的文字与坐标需要调整

plt.text(-8, 3.9, '   5星力荐   ', bbox=dict(boxstyle="round", fc="w",
                                          ec="0.5", alpha=0.7, linestyle='--', linewidth=0.6), size=10)
plt.text(-8.3, 2.9, '   4星推荐   ', bbox=dict(boxstyle="round", fc="w",
                                            ec="0.5", alpha=0.7, linestyle='--', linewidth=0.6), size=10)
plt.text(-8.3, 1.9, '   3星还行   ', bbox=dict(boxstyle="round", fc="w",
                                            ec="0.5", alpha=0.7, linestyle='--', linewidth=0.6), size=10)
plt.text(-8.3, 0.9, '   2星较差   ', bbox=dict(boxstyle="round", fc="w",
                                            ec="0.5", alpha=0.7, linestyle='--', linewidth=0.6), size=10)
plt.text(-8.3, -0.1, '   1星很差   ', bbox=dict(boxstyle="round", fc="w",
                                             ec="0.5", alpha=0.7, linestyle='--', linewidth=0.6), size=10)


plt.text(15,-0.05,"1%", fontproperties=WRYH,size = 9)
plt.text(15,0.95,"1%", fontproperties=WRYH,size = 9)
plt.text(19,1.95,"6%", fontproperties=WRYH,size = 9)
plt.text(41,2.95,"28%", fontproperties=WRYH,size = 9)
plt.text(76.5,3.95,"64%", fontproperties=WRYH,size = 9)

plt.text(-18.5,-0.05,"1%", fontproperties=WRYH,size = 9)
plt.text(-19.5,0.95,"2%", fontproperties=WRYH,size = 9)
plt.text(-29,1.95,"11%", fontproperties=WRYH,size = 9)
plt.text(-46,2.95,"28%", fontproperties=WRYH,size = 9)
plt.text(-76.3,3.95,"58%", fontproperties=WRYH,size = 9)

plt.text(-52,4.7,'   2009 - 2019   ',size = 13, bbox=dict(boxstyle="round", fc="w",
                                          ec="0.5", alpha=0.7, linestyle='-', linewidth=0.6),color = '#00C5D2')

plt.text(33,4.7,'   2020 - 2021   ',size = 13, bbox=dict(boxstyle="round", fc="w",
                                          ec="0.5", alpha=0.7, linestyle='-', linewidth=0.6),color = '#4D70F0')


plt.text(-38,5.5,'电影《阿凡达》评分十年前后对比',size = 20)

plt.text(-73,5.15,'-'*155)
plt.text(-73,-0.7,'-'*155)

plt.text(-73,-0.9,'数据来源：豆瓣电影      采集时间：4/5/2021',size = 8,alpha = 0.7, fontproperties=WRYH)
plt.text(33,-0.9,'公众号：「早起Python」｜「可视化图鉴」',size = 8,alpha = 0.9, fontproperties=WRYH)

plt.show()
